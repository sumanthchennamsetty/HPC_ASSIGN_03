# %% [markdown]
# <a href="https://colab.research.google.com/github/sumanthchennamsetty/HPC_ASSIGN_03/blob/main/Graph_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Threads and Throughput data for different workloads
threads = [1, 2, 4, 6, 8, 10, 12, 14, 16]  # Number of threads

# Throughput data for different workloads
workload_1 = [0.0588, 0.0588, 0.0526, 0.1176, 0.2, 0.4167, 0.2222, 0.2642, 0.3077]
workload_2 = [0.0588, 0.0588, 0.0526, 0.1176, 0.2, 0.4762, 0.4, 0.4667, 0.6957]
workload_3 = [0.0526, 0.0526, 0.0526, 0.1176, 0.3333, 0.4348, 0.4, 0.2642, 0.6667]

# Plotting the graph
plt.figure(figsize=(10, 6))  # Set the figure size

# Plot each workload
plt.plot(threads, workload_1, marker='o', label='0C-0I-50D')
plt.plot(threads, workload_2, marker='o', label='50C-25I-25D')
plt.plot(threads, workload_3, marker='o', label='100C-0I-0D')

# Graph labels and title
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.title('TAS Lock')
plt.legend()  # Show legend

# Show grid
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Threads and Throughput data for different workloads
threads = [1, 2, 4, 6, 8, 10, 12, 14, 16]  # Number of threads

# Throughput data for different workloads
workload_1 = [0.0714, 0.0625, 0.0769, 0.1111, 0.2105, 0.4, 0.48, 0.5833, 0.6667]
workload_2 = [0.0625, 0.125, 0.2105, 0.2857, 0.3636, 0.4167, 0.48, 0.5385, 0.6154]
workload_3 = [0.0769, 0.1176, 0.2353, 0.3, 0.3636, 0.4167, 0.4286, 0.5, 0.5333]

# Plotting the graph
plt.figure(figsize=(10, 6))  # Set the figure size

# Plot each workload
plt.plot(threads, workload_1, marker='o', label='0C-0I-50D')
plt.plot(threads, workload_2, marker='o', label='50C-25I-25D')
plt.plot(threads, workload_3, marker='o', label='100C-0I-0D')

# Graph labels and title
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.title('A Lock')
plt.legend()  # Show legend

# Show grid
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Threads and Throughput data for different workloads
threads = [1, 2, 4, 6, 8, 10, 12, 14, 16]  # Number of threads

# Throughput data for three different workloads
workload_1 = [0.0294, 0.0588, 0.1053, 0.1714, 0.2, 0.2439, 0.3077, 0.3889, 0.381]
workload_2 = [0.0313, 0.0714, 0.1176, 0.1765, 0.2105, 0.2564, 0.3333, 0.3415, 0.3721]
workload_3 = [0.0313, 0.0606, 0.1176, 0.1714, 0.2222, 0.2703, 0.3333, 0.3684, 0.4]

# Plotting the graph
plt.figure(figsize=(10, 6))  # Set the figure size

# Plot each workload
plt.plot(threads, workload_1, marker='o', label='0C-0I-50D')
plt.plot(threads, workload_2, marker='o', label='50C-25I-25D')
plt.plot(threads, workload_3, marker='o', label='100C-0I-0D')

# Graph labels and title
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.title('TTAS Lock')
plt.legend()  # Show legend

# Show grid
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Threads and Throughput data for different workloads
threads = [1, 2, 4, 6, 8, 10, 12, 14, 16]  # Number of threads

# Throughput data for three different workloads
workload_1 = [0.0588, 0.1176, 0.2222, 0.3158, 0.3636, 0.4762, 0.5455, 0.5833, 0.5517]
workload_2 = [0.04, 0.1053, 0.2105, 0.2857, 0.3810, 0.4545, 0.2264, 0.5600, 0.5161]
workload_3 = [0.0588, 0.1111, 0.2353, 0.2222, 0.3810, 0.3333, 0.2727, 0.3684, 0.7273]

# Plotting the graph
plt.figure(figsize=(10, 6))  # Set the figure size

# Plot each workload
plt.plot(threads, workload_1, marker='o', label='0C-0I-50D')
plt.plot(threads, workload_2, marker='o', label='50C-25I-25D')
plt.plot(threads, workload_3, marker='o', label='100C-0I-0D')

# Graph labels and title
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.title('MCS Lock')
plt.legend()  # Show legend

# Show grid
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Throughput values for different configurations and thread counts
workloads = {
    "0C-0I-50D": {
        1: 0.125, 2: 0.25, 4: 0.4, 6: 0.6667, 8: 0.8889, 10: 1.0, 12: 1.0, 14: 1.2727, 16: 1.4545
    },
    "50C-25I-25D": {
        1: 0.125, 2: 0.25, 4: 0.4444, 6: 0.5455, 8: 0.6667, 10: 0.8333, 12: 1.0, 14: 1.1667, 16: 1.2308
    },
    "100C-0I-0D": {
        1: 0.1429, 2: 0.25, 4: 0.4444, 6: 0.5455, 8: 0.7273, 10: 0.8333, 12: 1.0, 14: 0.9333, 16: 1.6
    }
}

plt.figure(figsize=(10, 6))  # Set the figure size

# Plotting the graph for each workload
for workload, values in workloads.items():
    plt.plot(list(values.keys()), list(values.values()), marker='o', label=workload)

# Adding labels and title
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.title('CLH Lock')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Throughput data for different scenarios
num_threads = [1, 2, 4, 6, 8, 10, 12, 14, 16]  # Number of threads
workload_0C_0I_50D = [0.01785714285714286, 0.03508771929824561, 0.061538461538461535, 0.0923076923076923, 0.11940298507462686, 0.14705882352941174, 0.1875, 0.1891891891891892, 0.23880597014925373]
workload_50C_25I_25D = [0.016666666666666666, 0.031746031746031744, 0.06896551724137931, 0.09836065573770492, 0.11764705882352941, 0.14705882352941174, 0.17647058823529413, 0.19718309859154928, 0.20512820512820512]
workload_100C_0I_0D = [0.016129032258064516, 0.03571428571428572, 0.05970149253731343, 0.08695652173913045, 0.11594202898550723, 0.14084507042253522, 0.2, 0.2028985507246377, 0.21917808219178084]

# Plotting the data
plt.figure(figsize=(10, 6))

plt.plot(num_threads, workload_0C_0I_50D, marker='o', label='0C-0I-50D')
plt.plot(num_threads, workload_50C_25I_25D, marker='o', label='50C-25I-25D')
plt.plot(num_threads, workload_100C_0I_0D, marker='o', label='100C-0I-0D')

plt.title('Backoff Lock')
plt.xlabel('Number of Threads')
plt.ylabel('Throughput')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Display the plot
plt.show()
